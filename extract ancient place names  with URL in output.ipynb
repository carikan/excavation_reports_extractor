# %%
#!/usr/bin/env python3
# ============================================================
# Batch Workflow: Extract Ancient Place‑Names from Turkish "Kazı Sonuçları" PDFs
#   (with PDF filename + original URL in output)
# Prerequisites (run once):
#   pip install pandas requests beautifulsoup4 PyMuPDF PyPDF2 zemberek-python
# ============================================================

import os
import re
import json
import logging
import requests
import pandas as pd
from bs4 import BeautifulSoup
from PyPDF2 import PdfReader
from zemberek import TurkishMorphology

# ─── Logger setup ─────────────────────────────────────────────
logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")
log = logging.getLogger(__name__)

# ─── Step 1 – Download & prepare Pleiades gazetteer ────────────
PLEIADES_CSV = "places.csv"
PLEIADES_URL = (
    "https://raw.githubusercontent.com/isawnyu/pleiades.datasets"
    "/main/data/gis/places.csv"
)
if not os.path.exists(PLEIADES_CSV):
    log.info("⬇️  Downloading Pleiades CSV…")
    r = requests.get(PLEIADES_URL)
    r.raise_for_status()
    with open(PLEIADES_CSV, "wb") as f:
        f.write(r.content)
    log.info("✅ Saved places.csv")

df = pd.read_csv(PLEIADES_CSV)
for col in ("representative_latitude", "representative_longitude", "title", "id"):
    if col not in df.columns:
        raise ValueError(f"❌ Missing column {col} in Pleiades CSV")

# filter for modern‐Turkey bounding box
df["reprLat"]  = pd.to_numeric(df["representative_latitude"],  errors="coerce")
df["reprLong"] = pd.to_numeric(df["representative_longitude"], errors="coerce")
df_tr = df[
    df["reprLat"].between(36,42) &
    df["reprLong"].between(26,45)
].copy()

ancient_places = set(df_tr["title"].str.lower().dropna())
log.info(f"✅ Loaded {len(ancient_places):,} place‑names inside Turkey")

# build lookup for coords & PID
place_lookup = {
    row["title"].lower(): {
        "pid": int(row["id"]),
        "lat": float(row["representative_latitude"]),
        "lon": float(row["representative_longitude"])
    }
    for _, row in df_tr.iterrows()
}

# ─── Step 2 – Scrape Ministry site for PDF URLs ───────────────
BASE      = "https://ukaas.ktb.gov.tr"
INDEX_URL = f"{BASE}/TR-389973/kazi-sonuclari-toplantisi.html"

log.info("🔎 Scraping excavation‐report PDF links …")
html       = requests.get(INDEX_URL).text
soup       = BeautifulSoup(html, "html.parser")
hrefs      = [a["href"] for a in soup.find_all("a", href=True) if a["href"].lower().endswith(".pdf")]
pdf_links  = [BASE + href for href in hrefs]
log.info(f"✅ Found {len(pdf_links)} PDF URLs on the site")

# build a map: local_filename → pdf_url
pdf_url_map = {}
for url in pdf_links:
    fn = os.path.basename(url.split("?")[0])
    pdf_url_map[fn] = url

# ─── Step 3 – Gather your local PDFs ──────────────────────────
pdf_dir   = "pdf_reports"
pdf_files = [
    os.path.join(pdf_dir, fn)
    for fn in os.listdir(pdf_dir)
    if fn.lower().endswith(".pdf")
]
if not pdf_files:
    raise RuntimeError(f"❌ No PDFs found in `{pdf_dir}/` – please drop them there.")
log.info(f"🔎 Found {len(pdf_files)} local PDFs to process")

# ─── Step 4 – Zemberek helper & PDF page extractor ───────────
zemb = TurkishMorphology.create_with_defaults()

def get_lemmas(token):
    analyses = zemb.analyze(token).analysis_results
    return [a.get_stem() for a in analyses] if analyses else [token]

def extract_pages(pdf_path):
    """Return list of (page_number, text) tuples, 1‑based."""
    reader = PdfReader(pdf_path)
    pages = [(i+1, page.extract_text() or "") for i, page in enumerate(reader.pages)]
    # fallback to PyMuPDF if all pages empty
    if all(not txt.strip() for _, txt in pages):
        import fitz
        doc = fitz.open(pdf_path)
        pages = [(i+1, doc[i].get_text("text")) for i in range(doc.page_count)]
    return pages

# ─── Step 5 – Batch loop over each PDF ───────────────────────
batch_results = []
for pdf_path in pdf_files:
    pdf_fn  = os.path.basename(pdf_path)
    pdf_url = pdf_url_map.get(pdf_fn)
    log.info(f"📄 Processing {pdf_fn}")
    pages = extract_pages(pdf_path)

    report = {
        "pdf_file": pdf_fn,
        "pdf_url":  pdf_url,
        "places":   {}
    }

    for page_num, text in pages:
        tokens = re.findall(r"\b([A-ZÇĞİÖŞÜ][a-zçğıöşü\-]+)\b", text)
        for tok in tokens:
            for lemma in get_lemmas(tok):
                key = lemma.lower()
                if key not in ancient_places:
                    continue
                ent = report["places"].setdefault(key, {
                    "pid":          place_lookup[key]["pid"],
                    "pleiades_url": f"https://pleiades.stoa.org/places/{place_lookup[key]['pid']}",
                    "lat":          place_lookup[key]["lat"],
                    "lon":          place_lookup[key]["lon"],
                    "occurrences":  []
                })
                # capture ±30 chars snippet
                idx     = text.find(tok)
                start   = max(0, idx - 30)
                snippet = text[start : idx + len(tok) + 30].replace("\n"," ")
                ent["occurrences"].append({
                    "token":   tok,
                    "page":    page_num,
                    "snippet": snippet
                })

    log.info(f"  → found {len(report['places'])} distinct places")
    batch_results.append(report)

# ─── Step 6 – Write out a single JSON ─────────────────────────
output = "all_reports_places.json"
with open(output, "w", encoding="utf-8") as f:
    json.dump(batch_results, f, ensure_ascii=False, indent=2)

log.info(f"🎉 Done – wrote `{output}`")
# Out:
# 2025-07-16 10:39:33,467 - __main__ - INFO
# Msg: ✅ Loaded 4,174 place‑names inside Turkey
#
# 2025-07-16 10:39:33,693 - __main__ - INFO
# Msg: 🔎 Scraping excavation‐report PDF links …
#
# 2025-07-16 10:39:36,313 - __main__ - INFO
# Msg: ✅ Found 0 PDF URLs on the site
#
# 2025-07-16 10:39:36,331 - __main__ - INFO
# Msg: 🔎 Found 73 local PDFs to process
#
# 2025-07-16 10:39:46,008 - zemberek.morphology.turkish_morphology - INFO
# Msg: TurkishMorphology instance initialized in 9.676278352737427
#
# 2025-07-16 10:39:46,008 - __main__ - INFO
# Msg: 📄 Processing 130346,02kazipdf.pdf
#
# 2025-07-16 10:40:33,028 - __main__ - INFO
# Msg:   → found 28 distinct places
#
# 2025-07-16 10:40:33,028 - __main__ - INFO
# Msg: 📄 Processing 130347,03kazipdf.pdf
#
# 2025-07-16 10:41:08,045 - __main__ - INFO
# Msg:   → found 19 distinct places
#
# 2025-07-16 10:41:08,045 - __main__ - INFO
# Msg: 📄 Processing 130348,04kazipdf.pdf
#
# 2025-07-16 10:42:41,036 - __main__ - INFO
# Msg:   → found 35 distinct places
#
# 2025-07-16 10:42:41,036 - __main__ - INFO
# Msg: 📄 Processing 130349,05kazipdf.pdf
#
# 2025-07-16 10:44:42,619 - __main__ - INFO
# Msg:   → found 46 distinct places
#
# 2025-07-16 10:44:42,619 - __main__ - INFO
# Msg: 📄 Processing 130350,06kazipdf.pdf
#
# 2025-07-16 10:46:36,277 - __main__ - INFO
# Msg:   → found 37 distinct places
#
# 2025-07-16 10:46:36,277 - __main__ - INFO
# Msg: 📄 Processing 130351,07kazipdf.pdf
#
# 2025-07-16 10:49:17,832 - __main__ - INFO
# Msg:   → found 49 distinct places
#
# 2025-07-16 10:49:17,847 - __main__ - INFO
# Msg: 📄 Processing 130352,08kazi1pdf.pdf
#
# 2025-07-16 10:50:56,203 - __main__ - INFO
# Msg:   → found 26 distinct places
#
# 2025-07-16 10:50:56,204 - __main__ - INFO
# Msg: 📄 Processing 130353,08kazi2pdf.pdf
#
# 2025-07-16 10:52:07,170 - __main__ - INFO
# Msg:   → found 32 distinct places
#
# 2025-07-16 10:52:07,171 - __main__ - INFO
# Msg: 📄 Processing 130354,09kazi1pdf.pdf
#
# 2025-07-16 10:53:50,442 - __main__ - INFO
# Msg:   → found 18 distinct places
#
# 2025-07-16 10:53:50,443 - __main__ - INFO
# Msg: 📄 Processing 130355,09kazi2pdf.pdf
#
# 2025-07-16 10:55:24,634 - __main__ - INFO
# Msg:   → found 21 distinct places
#
# 2025-07-16 10:55:24,635 - __main__ - INFO
# Msg: 📄 Processing 130356,10kazi1pdf.pdf
#
# 2025-07-16 10:56:54,612 - __main__ - INFO
# Msg:   → found 22 distinct places
#
# 2025-07-16 10:56:54,613 - __main__ - INFO
# Msg: 📄 Processing 130357,10kazi2pdf.pdf
#
# 2025-07-16 10:58:11,014 - __main__ - INFO
# Msg:   → found 34 distinct places
#
# 2025-07-16 10:58:11,015 - __main__ - INFO
# Msg: 📄 Processing 130358,11kazi1pdf.pdf
#
# 2025-07-16 10:59:25,420 - __main__ - INFO
# Msg:   → found 27 distinct places
#
# 2025-07-16 10:59:25,421 - __main__ - INFO
# Msg: 📄 Processing 130359,11kazi2pdf.pdf
#
# 2025-07-16 11:00:37,907 - __main__ - INFO
# Msg:   → found 33 distinct places
#
# 2025-07-16 11:00:37,908 - __main__ - INFO
# Msg: 📄 Processing 130360,12kazi1pdf.pdf
#
# 2025-07-16 11:02:10,204 - __main__ - INFO
# Msg:   → found 23 distinct places
#
# 2025-07-16 11:02:10,205 - __main__ - INFO
# Msg: 📄 Processing 130361,12kazi2pdf.pdf
#
# 2025-07-16 11:03:35,151 - __main__ - INFO
# Msg:   → found 43 distinct places
#
# 2025-07-16 11:03:35,152 - __main__ - INFO
# Msg: 📄 Processing 130362,13kazi1pdf.pdf
#
# 2025-07-16 11:05:04,213 - __main__ - INFO
# Msg:   → found 39 distinct places
#
# 2025-07-16 11:05:04,214 - __main__ - INFO
# Msg: 📄 Processing 130363,13kazi2pdf.pdf
#
# 2025-07-16 11:06:32,208 - __main__ - INFO
# Msg:   → found 29 distinct places
#
# 2025-07-16 11:06:32,210 - __main__ - INFO
# Msg: 📄 Processing 130364,14kazi1pdf.pdf
#
# 2025-07-16 11:08:47,153 - __main__ - INFO
# Msg:   → found 37 distinct places
#
# 2025-07-16 11:08:47,154 - __main__ - INFO
# Msg: 📄 Processing 130365,14kazi2pdf.pdf
#
# 2025-07-16 11:10:31,776 - __main__ - INFO
# Msg:   → found 40 distinct places
#
# 2025-07-16 11:10:31,777 - __main__ - INFO
# Msg: 📄 Processing 130366,15kazi1pdf.pdf
#
# 2025-07-16 11:12:44,841 - __main__ - INFO
# Msg:   → found 42 distinct places
#
# 2025-07-16 11:12:44,841 - __main__ - INFO
# Msg: 📄 Processing 130367,15kazi2pdf.pdf
#
# 2025-07-16 11:14:45,774 - __main__ - INFO
# Msg:   → found 59 distinct places
#
# 2025-07-16 11:14:45,775 - __main__ - INFO
# Msg: 📄 Processing 130368,16kazi1pdf.pdf
#
# 2025-07-16 11:16:20,333 - __main__ - INFO
# Msg:   → found 38 distinct places
#
# 2025-07-16 11:16:20,333 - __main__ - INFO
# Msg: 📄 Processing 130369,16kazi2pdf.pdf
#
# 2025-07-16 11:17:41,825 - __main__ - INFO
# Msg:   → found 35 distinct places
#
# 2025-07-16 11:17:41,825 - __main__ - INFO
# Msg: 📄 Processing 130371,17kazi1pdf.pdf
#
# 2025-07-16 11:19:22,559 - __main__ - INFO
# Msg:   → found 36 distinct places
#
# 2025-07-16 11:19:22,562 - __main__ - INFO
# Msg: 📄 Processing 130372,17kazi2pdf.pdf
#
# 2025-07-16 11:21:25,059 - __main__ - INFO
# Msg:   → found 53 distinct places
#
# 2025-07-16 11:21:25,060 - __main__ - INFO
# Msg: 📄 Processing 130373,18kazi1pdf.pdf
#
# 2025-07-16 11:23:37,597 - __main__ - INFO
# Msg:   → found 45 distinct places
#
# 2025-07-16 11:23:37,598 - __main__ - INFO
# Msg: 📄 Processing 130374,18kazi2pdf.pdf
#
# 2025-07-16 11:25:40,831 - __main__ - INFO
# Msg:   → found 49 distinct places
#
# 2025-07-16 11:25:40,831 - __main__ - INFO
# Msg: 📄 Processing 130375,19kazi1pdf.pdf
#
# 2025-07-16 11:29:06,163 - __main__ - INFO
# Msg:   → found 48 distinct places
#
# 2025-07-16 11:29:06,164 - __main__ - INFO
# Msg: 📄 Processing 130376,19kazi2pdf.pdf
#
# 2025-07-16 11:31:23,497 - __main__ - INFO
# Msg:   → found 59 distinct places
#
# 2025-07-16 11:31:23,498 - __main__ - INFO
# Msg: 📄 Processing 130377,20kazi1pdf.pdf
#
# 2025-07-16 11:33:36,913 - __main__ - INFO
# Msg:   → found 53 distinct places
#
# 2025-07-16 11:33:36,914 - __main__ - INFO
# Msg: 📄 Processing 130378,20kazi2pdf.pdf
#
# 2025-07-16 11:36:03,838 - __main__ - INFO
# Msg:   → found 61 distinct places
#
# 2025-07-16 11:36:03,839 - __main__ - INFO
# Msg: 📄 Processing 130379,21kazi1pdf.pdf
#
# 2025-07-16 11:38:31,982 - __main__ - INFO
# Msg:   → found 49 distinct places
#
# 2025-07-16 11:38:31,984 - __main__ - INFO
# Msg: 📄 Processing 130380,21kazi2pdf.pdf
#
# 2025-07-16 11:40:41,452 - __main__ - INFO
# Msg:   → found 53 distinct places
#
# 2025-07-16 11:40:41,453 - __main__ - INFO
# Msg: 📄 Processing 130381,22kazi1pdf.pdf
#
# 2025-07-16 11:42:26,422 - __main__ - INFO
# Msg:   → found 42 distinct places
#
# 2025-07-16 11:42:26,422 - __main__ - INFO
# Msg: 📄 Processing 130382,22kazi2pdf.pdf
#
# 2025-07-16 11:43:53,253 - __main__ - INFO
# Msg:   → found 55 distinct places
#
# 2025-07-16 11:43:53,254 - __main__ - INFO
# Msg: 📄 Processing 130383,23kazi1pdf.pdf
#
# 2025-07-16 11:45:32,217 - __main__ - INFO
# Msg:   → found 57 distinct places
#
# 2025-07-16 11:45:32,217 - __main__ - INFO
# Msg: 📄 Processing 130384,23kazi2pdf.pdf
#
# 2025-07-16 11:47:07,367 - __main__ - INFO
# Msg:   → found 53 distinct places
#
# 2025-07-16 11:47:07,367 - __main__ - INFO
# Msg: 📄 Processing 130385,24kazi1pdf.pdf
#
# 2025-07-16 11:49:02,490 - __main__ - INFO
# Msg:   → found 67 distinct places
#
# 2025-07-16 11:49:02,490 - __main__ - INFO
# Msg: 📄 Processing 130386,24kazi2pdf.pdf
#
# 2025-07-16 11:50:54,643 - __main__ - INFO
# Msg:   → found 73 distinct places
#
# 2025-07-16 11:50:54,643 - __main__ - INFO
# Msg: 📄 Processing 130387,25kazi1pdf.pdf
#
# 2025-07-16 11:52:31,885 - __main__ - INFO
# Msg:   → found 59 distinct places
#
# 2025-07-16 11:52:31,885 - __main__ - INFO
# Msg: 📄 Processing 130388,25kazi2pdf.pdf
#
# 2025-07-16 11:54:12,798 - __main__ - INFO
# Msg:   → found 60 distinct places
#
# 2025-07-16 11:54:12,798 - __main__ - INFO
# Msg: 📄 Processing 130389,26kazi1pdf.pdf
#
# 2025-07-16 11:54:31,220 - __main__ - INFO
# Msg:   → found 78 distinct places
#
# 2025-07-16 11:54:31,220 - __main__ - INFO
# Msg: 📄 Processing 130390,26kazi2pdf.pdf
#
# 2025-07-16 11:54:44,882 - __main__ - INFO
# Msg:   → found 58 distinct places
#
# 2025-07-16 11:54:44,882 - __main__ - INFO
# Msg: 📄 Processing 130391,27kazi1pdf.pdf
#
# 2025-07-16 11:54:57,190 - __main__ - INFO
# Msg:   → found 68 distinct places
#
# 2025-07-16 11:54:57,190 - __main__ - INFO
# Msg: 📄 Processing 130392,27kazi2pdf.pdf
#
# 2025-07-16 11:55:08,913 - __main__ - INFO
# Msg:   → found 54 distinct places
#
# 2025-07-16 11:55:08,913 - __main__ - INFO
# Msg: 📄 Processing 130393,28kazi1pdf.pdf
#
# 2025-07-16 11:55:28,480 - __main__ - INFO
# Msg:   → found 63 distinct places
#
# 2025-07-16 11:55:28,480 - __main__ - INFO
# Msg: 📄 Processing 130394,28kazi2pdf.pdf
#
# 2025-07-16 11:55:49,916 - __main__ - INFO
# Msg:   → found 84 distinct places
# 2025-07-16 11:55:49,916 - __main__ - INFO
# Msg: 📄 Processing 130395,29kazi1pdf.pdf
#
# 2025-07-16 11:56:07,065 - __main__ - INFO
# Msg:   → found 53 distinct places
#
# 2025-07-16 11:56:07,065 - __main__ - INFO
# Msg: 📄 Processing 130396,29kazi2pdf.pdf
#
# 2025-07-16 11:56:23,792 - __main__ - INFO
# Msg:   → found 76 distinct places
#
# 2025-07-16 11:56:23,792 - __main__ - INFO
# Msg: 📄 Processing 130397,29kazi3pdf.pdf
#
# 2025-07-16 11:56:43,142 - __main__ - INFO
# Msg:   → found 74 distinct places
#
# 2025-07-16 11:56:43,142 - __main__ - INFO
# Msg: 📄 Processing 130398,30kazi2pdf.pdf
#
# 2025-07-16 11:56:59,262 - __main__ - INFO
# Msg:   → found 59 distinct places
#
# 2025-07-16 11:56:59,262 - __main__ - INFO
# Msg: 📄 Processing 130399,30kazi1pdf.pdf
#
# 2025-07-16 11:57:14,879 - __main__ - INFO
# Msg:   → found 61 distinct places
#
# 2025-07-16 11:57:14,879 - __main__ - INFO
# Msg: 📄 Processing 130400,30kazi3pdf.pdf
#
# 2025-07-16 11:57:29,046 - __main__ - INFO
# Msg:   → found 71 distinct places
#
# 2025-07-16 11:57:29,046 - __main__ - INFO
# Msg: 📄 Processing 130401,30kazi4pdf.pdf
#
# 2025-07-16 11:57:41,515 - __main__ - INFO
# Msg:   → found 57 distinct places
#
# 2025-07-16 11:57:41,515 - __main__ - INFO
# Msg: 📄 Processing 130402,31kazi1pdf.pdf
#
# 2025-07-16 11:58:00,770 - __main__ - INFO
# Msg:   → found 52 distinct places
#
# 2025-07-16 11:58:00,770 - __main__ - INFO
# Msg: 📄 Processing 130403,31kazi2pdf.pdf
#
# 2025-07-16 11:58:16,407 - __main__ - INFO
# Msg:   → found 51 distinct places
#
# 2025-07-16 11:58:16,407 - __main__ - INFO
# Msg: 📄 Processing 130404,31kazi3pdf.pdf
#
# 2025-07-16 11:58:33,376 - __main__ - INFO
# Msg:   → found 52 distinct places
#
# 2025-07-16 11:58:33,376 - __main__ - INFO
# Msg: 📄 Processing 130405,31kazi4pdf.pdf
#
# 2025-07-16 11:58:53,160 - __main__ - INFO
# Msg:   → found 55 distinct places
#
# 2025-07-16 11:58:53,160 - __main__ - INFO
# Msg: 📄 Processing 130406,32kazi1pdf.pdf
#
# 2025-07-16 11:59:14,078 - __main__ - INFO
# Msg:   → found 54 distinct places
#
# 2025-07-16 11:59:14,078 - __main__ - INFO
# Msg: 📄 Processing 130407,32kazi2pdf.pdf
#
# 2025-07-16 11:59:34,242 - __main__ - INFO
# Msg:   → found 61 distinct places
#
# 2025-07-16 11:59:34,242 - __main__ - INFO
# Msg: 📄 Processing 130408,32kazi3pdf.pdf
#
# 2025-07-16 11:59:51,515 - __main__ - INFO
# Msg:   → found 59 distinct places
#
# 2025-07-16 11:59:51,515 - __main__ - INFO
# Msg: 📄 Processing 130409,32kazi4pdf.pdf
#
# 2025-07-16 12:00:09,808 - __main__ - INFO
# Msg:   → found 55 distinct places
#
# 2025-07-16 12:00:09,808 - __main__ - INFO
# Msg: 📄 Processing 27146,35kazi1.pdf
#
# 2025-07-16 12:00:41,158 - __main__ - INFO
# Msg:   → found 57 distinct places
#
# 2025-07-16 12:00:41,158 - __main__ - INFO
# Msg: 📄 Processing 44-kazi-sonuclari-toplantisi-bildirileri6-ciltpdf.pdf
#
# 2025-07-16 12:01:01,453 - __main__ - INFO
# Msg:   → found 65 distinct places
#
# 2025-07-16 12:01:01,453 - __main__ - INFO
# Msg: 📄 Processing 4651,33kazi1.pdf
#
# 2025-07-16 12:01:18,466 - __main__ - INFO
# Msg:   → found 57 distinct places
#
# 2025-07-16 12:01:18,466 - __main__ - INFO
# Msg: 📄 Processing 4652,33kazi2.pdf
#
# 2025-07-16 12:01:35,509 - __main__ - INFO
# Msg:   → found 61 distinct places
#
# 2025-07-16 12:01:35,509 - __main__ - INFO
# Msg: 📄 Processing 4653,33kazi3.pdf
#
# 2025-07-16 12:01:54,872 - __main__ - INFO
# Msg:   → found 63 distinct places
#
# 2025-07-16 12:01:54,872 - __main__ - INFO
# Msg: 📄 Processing 4654,33kazi4.pdf
#
# 2025-07-16 12:02:44,093 - __main__ - INFO
# Msg:   → found 74 distinct places
#
# 2025-07-16 12:02:44,093 - __main__ - INFO
# Msg: 📄 Processing 7332,34kazi1.pdf
#
# 2025-07-16 12:03:00,428 - __main__ - INFO
# Msg:   → found 45 distinct places
#
# 2025-07-16 12:03:00,428 - __main__ - INFO
# Msg: 📄 Processing 7334,34kazi2.pdf
#
# 2025-07-16 12:03:18,394 - __main__ - INFO
# Msg:   → found 56 distinct places
#
# 2025-07-16 12:03:18,394 - __main__ - INFO
# Msg: 📄 Processing 7335,34kazi3.pdf
#
# 2025-07-16 12:03:36,841 - __main__ - INFO
# Msg:   → found 64 distinct places
#
# 2025-07-16 12:03:36,841 - __main__ - INFO
# Msg: 📄 Processing demo1.pdf
#
# 2025-07-16 12:03:57,206 - __main__ - INFO
# Msg:   → found 65 distinct places
#
# 2025-07-16 12:03:57,578 - __main__ - INFO
# Msg: 🎉 Done – wrote `all_reports_places.json`
